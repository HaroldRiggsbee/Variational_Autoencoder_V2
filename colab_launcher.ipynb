# %%
from google.colab import drive
import sys
import os

# 1. Mount Google Drive
drive.mount('/content/drive')

# 2. Path to your folder (Adjust this to match your Drive exactly)
project_root = '/content/drive/MyDrive/Autoencoder V2'

# 3. Add to system path so 'import encoder' works
if project_root not in sys.path:
    sys.path.append(project_root)

# 4. Change working directory so 'samples/' and 'spectrograms/' are found
os.chdir(project_root)

print(f"Current Working Directory: {os.getcwd()}")

# %%
# Install any missing libraries
# !pip install torchinfo librosa sklearn

# Execute your main script
# %run main.py
